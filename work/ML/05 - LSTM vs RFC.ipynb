# %%
import pandas as pd

start_time = pd.Timestamp.now()
df_jan = pd.read_csv('../../data/bicing/processed/months/2023_01_STATIONS.csv')
df_feb = pd.read_csv('../../data/bicing/processed/months/2023_02_STATIONS.csv')
df_march = pd.read_csv('../../data/bicing/processed/months/2023_03_STATIONS.csv')
df_april = pd.read_csv('../../data/bicing/processed/months/2023_04_STATIONS.csv')
df_may = pd.read_csv('../../data/bicing/processed/months/2023_05_STATIONS.csv')
df_june = pd.read_csv('../../data/bicing/processed/months/2023_06_STATIONS.csv')
df_july = pd.read_csv('../../data/bicing/processed/months/2023_07_STATIONS.csv')
df_aug = pd.read_csv('../../data/bicing/processed/months/2023_08_STATIONS.csv')
df_sep = pd.read_csv('../../data/bicing/processed/months/2023_09_STATIONS.csv')
df_oct = pd.read_csv('../../data/bicing/processed/months/2023_10_STATIONS.csv')
df_nov = pd.read_csv('../../data/bicing/processed/months/2023_11_STATIONS.csv')
df_dec = pd.read_csv('../../data/bicing/processed/months/2023_12_STATIONS.csv')

# %%
df_jan = df_jan[(df_jan['month'] == 1) & (df_jan['year'] == 2023)]
df_feb = df_feb[(df_feb['month'] == 2) & (df_feb['year'] == 2023)]
df_march = df_march[(df_march['month'] == 3) & (df_march['year'] == 2023)]
df_april = df_april[(df_april['month'] == 4) & (df_april['year'] == 2023)]
df_may = df_may[(df_may['month'] == 5) & (df_may['year'] == 2023)]
df_june = df_june[(df_june['month'] == 6) & (df_june['year'] == 2023)]
df_july = df_july[(df_july['month'] == 7) & (df_july['year'] == 2023)]
df_aug = df_aug[(df_aug['month'] == 8) & (df_aug['year'] == 2023)]
df_sep = df_sep[(df_sep['month'] == 9) & (df_sep['year'] == 2023)]
df_oct = df_oct[(df_oct['month'] == 10) & (df_oct['year'] == 2023)]
df_nov = df_nov[(df_nov['month'] == 11) & (df_nov['year'] == 2023)]
df_dec = df_dec[(df_dec['month'] == 12) & (df_dec['year'] == 2023)]

# %%
df_2023 = pd.concat([df_jan, df_feb, df_march, df_april, df_may, df_june, df_july, df_aug, df_sep, df_oct, df_nov, df_dec])
df_2023.sort_values(by=['grouped_date'], inplace=True)
df_2023.head()
# Out:
#       station_id  num_bikes_available  num_bikes_available_types.mechanical  \
# 3826           1                   37                                    35
# 4396         185                    9                                     4
# 4397         188                   23                                    20
# 4398         196                    6                                     1
# 4399         201                    2                                     0
#
#       num_bikes_available_types.ebike  num_docks_available      status  \
# 3826                                2                    9  IN_SERVICE
# 4396                                5                    8  IN_SERVICE
# 4397                                3                    4  IN_SERVICE
# 4398                                5                   21  IN_SERVICE
# 4399                                2                   22  IN_SERVICE
#
#       is_renting  is_returning  year  month  day  hour  grouped_minute  \
# 3826           1             1  2023      1    1     0               0
# 4396           1             1  2023      1    1     0               0
# 4397           1             1  2023      1    1     0               0
# 4398           1             1  2023      1    1     0               0
# 4399           1             1  2023      1    1     0               0
#
#       day_of_week  is_weekend   grouped_date  docking_available  \
# 3826            6           1  2023-1-1 0:00               True
# 4396            6           1  2023-1-1 0:00               True
# 4397            6           1  2023-1-1 0:00               True
# 4398            6           1  2023-1-1 0:00               True
# 4399            6           1  2023-1-1 0:00               True
#
#       bikes_available  bikes_available.mechanical  bikes_available.ebike
# 3826             True                        True                   True
# 4396             True                        True                   True
# 4397             True                        True                   True
# 4398             True                        True                   True
# 4399             True                       False                   True

# %%
df_2023['grouped_date'] = pd.to_datetime(df_2023['grouped_date'])
df_2023['season'] = df_2023['grouped_date'].dt.month.apply(lambda x: 'Spring' if x in [3, 4, 5] else 'Summer' if x in [6, 7, 8] else 'Autumn' if x in [9, 10, 11] else 'Winter')
df_2023.head(4)
# Out:
#       station_id  num_bikes_available  num_bikes_available_types.mechanical  \
# 3826           1                   37                                    35
# 4396         185                    9                                     4
# 4397         188                   23                                    20
# 4398         196                    6                                     1
#
#       num_bikes_available_types.ebike  num_docks_available      status  \
# 3826                                2                    9  IN_SERVICE
# 4396                                5                    8  IN_SERVICE
# 4397                                3                    4  IN_SERVICE
# 4398                                5                   21  IN_SERVICE
#
#       is_renting  is_returning  year  month  ...  hour  grouped_minute  \
# 3826           1             1  2023      1  ...     0               0
# 4396           1             1  2023      1  ...     0               0
# 4397           1             1  2023      1  ...     0               0
# 4398           1             1  2023      1  ...     0               0
#
#       day_of_week  is_weekend  grouped_date docking_available  \
# 3826            6           1    2023-01-01              True
# 4396            6           1    2023-01-01              True
# 4397            6           1    2023-01-01              True
# 4398            6           1    2023-01-01              True
#
#       bikes_available  bikes_available.mechanical  bikes_available.ebike  \
# 3826             True                        True                   True
# 4396             True                        True                   True
# 4397             True                        True                   True
# 4398             True                        True                   True
#
#       season
# 3826  Winter
# 4396  Winter
# 4397  Winter
# 4398  Winter
#
# [4 rows x 21 columns]

# %%
df_weather = pd.read_csv('../../data/weather_clean.csv')

df_weather.head(3)
# Out:
#          date  hour  temperature  rainfall
# 0  2023-01-01     0           15       0.0
# 1  2023-01-01     1           14       0.0
# 2  2023-01-01     2           14       0.0

# %%
df_weather['date'] = pd.to_datetime(df_weather['date'])
df_weather['day'] = df_weather['date'].dt.day.astype(int)
df_weather['month'] = df_weather['date'].dt.month.astype(int)
df_weather['year'] = df_weather['date'].dt.year.astype(int)
df_weather['hour'] = df_weather['hour'].astype(int)

# %%
df_2023_weather = pd.merge(df_2023, df_weather, on=['year', 'month', 'day', 'hour'], how='left')
df_2023_weather.head(3)
# Out:
#    station_id  num_bikes_available  num_bikes_available_types.mechanical  \
# 0           1                   37                                    35
# 1         185                    9                                     4
# 2         188                   23                                    20
#
#    num_bikes_available_types.ebike  num_docks_available      status  \
# 0                                2                    9  IN_SERVICE
# 1                                5                    8  IN_SERVICE
# 2                                3                    4  IN_SERVICE
#
#    is_renting  is_returning  year  month  ...  is_weekend  grouped_date  \
# 0           1             1  2023      1  ...           1    2023-01-01
# 1           1             1  2023      1  ...           1    2023-01-01
# 2           1             1  2023      1  ...           1    2023-01-01
#
#    docking_available  bikes_available  bikes_available.mechanical  \
# 0               True             True                        True
# 1               True             True                        True
# 2               True             True                        True
#
#   bikes_available.ebike  season       date  temperature  rainfall
# 0                  True  Winter 2023-01-01           15       0.0
# 1                  True  Winter 2023-01-01           15       0.0
# 2                  True  Winter 2023-01-01           15       0.0
#
# [3 rows x 24 columns]

# %%
station_info_df = pd.read_csv('../../data/bicing/processed/2024_STATION_LOCATIONS.csv', dtype={'post_code': str})
station_info_df.head()
# Out:
#    station_id        lat       lon  altitude post_code  capacity  \
# 0           1  41.397978  2.180107      16.0     08013        46
# 1           2  41.395488  2.177198      17.0     08013        29
# 2           3  41.394156  2.181331      11.0     08013        27
# 3           4  41.393317  2.181248       8.0     08013        21
# 4           5  41.391103  2.180176       7.0     08018        39
#
#                                address    district
# 0        GRAN VIA CORTS CATALANES, 760    Eixample
# 1                C/ ROGER DE FLOR, 126    Eixample
# 2                        C/ NÀPOLS, 82    Eixample
# 3                         C/ RIBES, 13    Eixample
# 4  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)  Sant Martí

# %%
df_2023_weather_station = pd.merge(df_2023_weather, station_info_df, on='station_id', how='left')
df_2023_weather_station.head()
# Out:
#    station_id  num_bikes_available  num_bikes_available_types.mechanical  \
# 0           1                   37                                    35
# 1         185                    9                                     4
# 2         188                   23                                    20
# 3         196                    6                                     1
# 4         201                    2                                     0
#
#    num_bikes_available_types.ebike  num_docks_available      status  \
# 0                                2                    9  IN_SERVICE
# 1                                5                    8  IN_SERVICE
# 2                                3                    4  IN_SERVICE
# 3                                5                   21  IN_SERVICE
# 4                                2                   22  IN_SERVICE
#
#    is_renting  is_returning  year  month  ...       date  temperature  \
# 0           1             1  2023      1  ... 2023-01-01           15
# 1           1             1  2023      1  ... 2023-01-01           15
# 2           1             1  2023      1  ... 2023-01-01           15
# 3           1             1  2023      1  ... 2023-01-01           15
# 4           1             1  2023      1  ... 2023-01-01           15
#
#    rainfall        lat       lon altitude  post_code  capacity  \
# 0       0.0  41.397978  2.180107     16.0      08013      46.0
# 1       0.0  41.370372  2.138944     20.0      08014      17.0
# 2       0.0  41.375695  2.135857     30.0      08014      27.0
# 3       0.0  41.383261  2.139266     38.0      08029      27.0
# 4       0.0  41.387806  2.134422     55.0      08029      24.0
#
#                          address        district
# 0  GRAN VIA CORTS CATALANES, 760        Eixample
# 1                     C/GAVÀ, 81  Sants-Montjuïc
# 2     PG. SANT ANTONI /PL. SANTS  Sants-Montjuïc
# 3                  C/ BERLÍN, 38       Les Corts
# 4               C/ NUMÀNCIA, 136       Les Corts
#
# [5 rows x 31 columns]

# %%
df_2023_weather_station.columns
# Out:
# Index(['station_id', 'num_bikes_available', 'num_bikes_available_types.mechanical', 'num_bikes_available_types.ebike', 'num_docks_available', 'status', 'is_renting', 'is_returning', 'year', 'month', 'day', 'hour', 'grouped_minute', 'day_of_week', 'is_weekend', 'grouped_date', 'docking_available', 'bikes_available', 'bikes_available.mechanical', 'bikes_available.ebike', 'season', 'date', 'temperature', 'rainfall', 'lat', 'lon', 'altitude', 'post_code', 'capacity', 'address', 'district'], dtype='object')

# %%
columns_to_keep = ['station_id', 'num_bikes_available',
                   'num_bikes_available_types.mechanical',
                   'num_bikes_available_types.ebike', 'num_docks_available', 'status',
                   'is_renting', 'is_returning', 'day_of_week', 'is_weekend', 'grouped_date',
                   'docking_available', 'bikes_available', 'bikes_available.mechanical',
                   'bikes_available.ebike', 'temperature', 'rainfall', 'lat', 'lon', 'post_code', 'altitude', 'capacity', 'year', 'month', 'day', 'hour','season'
       'grouped_minute']

df_2023_ml = df_2023_weather_station
df_2023_ml.head()
# Out:
#    station_id  num_bikes_available  num_bikes_available_types.mechanical  num_bikes_available_types.ebike  num_docks_available      status  is_renting  is_returning  year  month  day  hour  grouped_minute  day_of_week  is_weekend grouped_date  docking_available  bikes_available  bikes_available.mechanical  bikes_available.ebike  season       date  temperature  rainfall        lat       lon  altitude post_code  capacity                        address        district
# 0           1                   37                                    35                                2                    9  IN_SERVICE           1             1  2023      1    1     0               0            6           1   2023-01-01               True             True                        True                   True  Winter 2023-01-01           15       0.0  41.397978  2.180107      16.0     08013      46.0  GRAN VIA CORTS CATALANES, 760        Eixample
# 1         185                    9                                     4                                5                    8  IN_SERVICE           1             1  2023      1    1     0               0            6           1   2023-01-01               True             True                        True                   True  Winter 2023-01-01           15       0.0  41.370372  2.138944      20.0     08014      17.0                     C/GAVÀ, 81  Sants-Montjuïc
# 2         188                   23                                    20                                3                    4  IN_SERVICE           1             1  2023      1    1     0               0            6           1   2023-01-01               True             True                        True                   True  Winter 2023-01-01           15       0.0  41.375695  2.135857      30.0     08014      27.0     PG. SANT ANTONI /PL. SANTS  Sants-Montjuïc
# 3         196                    6                                     1                                5                   21  IN_SERVICE           1             1  2023      1    1     0               0            6           1   2023-01-01               True             True                        True                   True  Winter 2023-01-01           15       0.0  41.383261  2.139266      38.0     08029      27.0                  C/ BERLÍN, 38       Les Corts
# 4         201                    2                                     0                                2                   22  IN_SERVICE           1             1  2023      1    1     0               0            6           1   2023-01-01               True             True                       False                   True  Winter 2023-01-01           15       0.0  41.387806  2.134422      55.0     08029      24.0               C/ NUMÀNCIA, 136       Les Corts

# %%
df_2023_ml[df_2023_ml['capacity'].isnull()]['station_id'].unique()
#Station 520 missing information
df_2023_ml = df_2023_ml[df_2023_ml['station_id'] != 520]

# %%
df_2023_ml.isnull().sum()
# Out:
# station_id                              0
# num_bikes_available                     0
# num_bikes_available_types.mechanical    0
# num_bikes_available_types.ebike         0
# num_docks_available                     0
# status                                  0
# is_renting                              0
# is_returning                            0
# year                                    0
# month                                   0
# day                                     0
# hour                                    0
# grouped_minute                          0
# day_of_week                             0
# is_weekend                              0
# grouped_date                            0
# docking_available                       0
# bikes_available                         0
# bikes_available.mechanical              0
# bikes_available.ebike                   0
# season                                  0
# date                                    0
# temperature                             0
# rainfall                                0
# lat                                     0
# lon                                     0
# altitude                                0
# post_code                               0
# capacity                                0
# address                                 0
# district                                0
# dtype: int64

# %%
df_2023_ml['grouped_date'] = pd.to_datetime(df_2023_ml['grouped_date'])
# Out:
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_64682/2227770550.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_ml['grouped_date'] = pd.to_datetime(df_2023_ml['grouped_date'])

# %%
holidays = ['01/06/2023', '04/07/2023', '04/10/2023', '05/01/2023', '06/24/2023', '08/15/2023', '09/11/2023', '10/12/2023', '11/01/2023', '12/06/2023', '12/08/2023', '12/25/2023', '12/26/2023']
df_2023_ml['is_holiday'] = df_2023_ml['grouped_date'].isin(holidays)
df_2023_ml[df_2023_ml['is_holiday'] == True]['grouped_date']
# Out:
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_64682/2482286237.py:2: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df_2023_ml['is_holiday'] = df_2023_ml['grouped_date'].isin(holidays)
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_64682/2482286237.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_ml['is_holiday'] = df_2023_ml['grouped_date'].isin(holidays)
# 1935575    2023-01-06
# 1935576    2023-01-06
# 1935577    2023-01-06
# 1935578    2023-01-06
# 1935579    2023-01-06
#               ...
# 26002052   2023-09-11
# 26002053   2023-09-11
# 26002054   2023-09-11
# 26002055   2023-09-11
# 26002056   2023-09-11
# Name: grouped_date, Length: 8928, dtype: datetime64[ns]

# %%
df_2023_ml['percentage_docks_available'] = df_2023_ml['num_docks_available'] / df_2023_ml['capacity']
df_2023_ml.head(5)
# Out:
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_64682/150156111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_ml['percentage_docks_available'] = df_2023_ml['num_docks_available'] / df_2023_ml['capacity']
#    station_id  num_bikes_available  num_bikes_available_types.mechanical  \
# 0           1                   37                                    35
# 1         185                    9                                     4
# 2         188                   23                                    20
# 3         196                    6                                     1
# 4         201                    2                                     0
#
#    num_bikes_available_types.ebike  num_docks_available      status  \
# 0                                2                    9  IN_SERVICE
# 1                                5                    8  IN_SERVICE
# 2                                3                    4  IN_SERVICE
# 3                                5                   21  IN_SERVICE
# 4                                2                   22  IN_SERVICE
#
#    is_renting  is_returning  year  month  ...  rainfall        lat       lon  \
# 0           1             1  2023      1  ...       0.0  41.397978  2.180107
# 1           1             1  2023      1  ...       0.0  41.370372  2.138944
# 2           1             1  2023      1  ...       0.0  41.375695  2.135857
# 3           1             1  2023      1  ...       0.0  41.383261  2.139266
# 4           1             1  2023      1  ...       0.0  41.387806  2.134422
#
#    altitude  post_code capacity                        address  \
# 0      16.0      08013     46.0  GRAN VIA CORTS CATALANES, 760
# 1      20.0      08014     17.0                     C/GAVÀ, 81
# 2      30.0      08014     27.0     PG. SANT ANTONI /PL. SANTS
# 3      38.0      08029     27.0                  C/ BERLÍN, 38
# 4      55.0      08029     24.0               C/ NUMÀNCIA, 136
#
#          district  is_holiday  percentage_docks_available
# 0        Eixample       False                    0.195652
# 1  Sants-Montjuïc       False                    0.470588
# 2  Sants-Montjuïc       False                    0.148148
# 3       Les Corts       False                    0.777778
# 4       Les Corts       False                    0.916667
#
# [5 rows x 33 columns]

# %%
df_2023_ml['week_number'] = df_2023_ml['grouped_date'].dt.isocalendar().week
# Out:
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_64682/3535076674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_ml['week_number'] = df_2023_ml['grouped_date'].dt.isocalendar().week

# %%
df_2023_ml['is_summer'] = df_2023_ml['season'] == 'Summer'
# Out:
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_64682/1510188512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023_ml['is_summer'] = df_2023_ml['season'] == 'Summer'

# %%
end_time = pd.Timestamp.now()
#print(f"Time to process: {end_time - start_time} ml")
len(df_2023_ml)
df_2023_ml.columns
# Out:
# Index(['station_id', 'num_bikes_available',
#        'num_bikes_available_types.mechanical',
#        'num_bikes_available_types.ebike', 'num_docks_available', 'status',
#        'is_renting', 'is_returning', 'year', 'month', 'day', 'hour',
#        'grouped_minute', 'day_of_week', 'is_weekend', 'grouped_date',
#        'docking_available', 'bikes_available', 'bikes_available.mechanical',
#        'bikes_available.ebike', 'season', 'date', 'temperature', 'rainfall',
#        'lat', 'lon', 'altitude', 'post_code', 'capacity', 'address',
#        'district', 'is_holiday', 'percentage_docks_available', 'week_number',
#        'is_summer'],
#       dtype='object')

# %%
#filter stations if needed
stations_ids = df_2023_ml['station_id'].unique()
# get 5 random stations
import random
filter_stations = random.sample(list(stations_ids), 5)
#filter_stations = [57, 446]
filter_stations = [57, 32, 31, 378, 446]
df_a = df_2023_ml[df_2023_ml['station_id'].isin(filter_stations)]
#df_a = df_2023_ml
df_a.columns
# Out:
# Index(['station_id', 'num_bikes_available',
#        'num_bikes_available_types.mechanical',
#        'num_bikes_available_types.ebike', 'num_docks_available', 'status',
#        'is_renting', 'is_returning', 'year', 'month', 'day', 'hour',
#        'grouped_minute', 'day_of_week', 'is_weekend', 'grouped_date',
#        'docking_available', 'bikes_available', 'bikes_available.mechanical',
#        'bikes_available.ebike', 'season', 'date', 'temperature', 'rainfall',
#        'lat', 'lon', 'altitude', 'post_code', 'capacity', 'address',
#        'district', 'is_holiday', 'percentage_docks_available', 'week_number',
#        'is_summer'],
#       dtype='object')

# %% [markdown]
# # Reduce Dataset

# %% [markdown]
# ## May

# %% [markdown]
# ### Prepare Data DF

# %%
#May has the most data - 31 days  * 24 hours * 4 quarters = 2976
# Filter May
df_may = df_a[df_a['month'] == 5]
#only columns to be able to drop duplicates
features = ['day_of_week', 'hour', 'grouped_minute', 'temperature', 'rainfall',
            'capacity',  'altitude', 'is_weekend', 'season', 'month','docking_available','grouped_date','station_id']
df_may = df_may[features]

# drop duplicates
print(len(df_may))
df_may.drop_duplicates(inplace=True)
print(len(df_may))

# check for missing values
df_may.isna().sum()

#find duplicated records by grouped_date
print(df_may['grouped_date'].duplicated().sum())
#keep one record per grouped_date, keep docking_available as the 0 of the duplicates
df_may.drop_duplicates(subset='grouped_date', keep='last', inplace=True)
print(df_may['grouped_date'].duplicated().sum())
# Out:
# 25220
# 15236
# 12445
# 0

# %% [markdown]
# ### Create May dates DF

# %%
df_may_dates = pd.date_range(start='2023-05-01', end='2023-06-1', freq='15T')
#Delete June 1st
df_may_dates = df_may_dates[:-1]
len(df_may_dates)
# Out:
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_37086/2312929128.py:1: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_may_dates = pd.date_range(start='2023-05-01', end='2023-06-1', freq='15T')
# 2976

# %% [markdown]
# ### Check missing values in the Dates

# %%
missing_quarters = ~df_may_dates.isin(df_may['grouped_date'])
len(df_may_dates[missing_quarters])
# Out:
# 185

# %% [markdown]
# ### fill in data from previous records

# %%
#add missing quarters interpolated
missing_quarters = df_may_dates[missing_quarters]
# create a dataframe with the missing quarters
df_missing = pd.DataFrame(missing_quarters, columns=['grouped_date'])
#merge with the original dataframe
df_may_merged = pd.merge(df_may, df_missing, on='grouped_date', how='outer')
#sort by date
#df_may_merged.sort_values(['station_id', 'grouped_date'], inplace=True)
df_may_filled = df_may_merged.sort_values(['station_id', 'grouped_date']).fillna(method='ffill')
df_may_filled.isna().sum()
# Out:
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_37086/893244272.py:9: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_may_filled = df_may_merged.sort_values(['station_id', 'grouped_date']).fillna(method='ffill')
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_37086/893244272.py:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_may_filled = df_may_merged.sort_values(['station_id', 'grouped_date']).fillna(method='ffill')
# day_of_week          0
# hour                 0
# grouped_minute       0
# temperature          0
# rainfall             0
# capacity             0
# altitude             0
# is_weekend           0
# season               0
# month                0
# docking_available    0
# grouped_date         0
# station_id           0
# dtype: int64

# %% [markdown]
# ### Check Dates field again in case of fill in

# %%
df_may_filled['day_of_week'] = df_may_filled['grouped_date'].dt.dayofweek
df_may_filled['hour'] = df_may_filled['grouped_date'].dt.hour
df_may_filled['grouped_minute'] = df_may_filled['grouped_date'].dt.minute 
df_may_filled['day'] = df_may_filled['grouped_date'].dt.day
df_may_filled.head(3)
# Out:
#      day_of_week  hour  grouped_minute  temperature  rainfall  capacity  \
# 73             0    18              15         17.0       0.0      18.0
# 79             0    19              45         17.0       0.0      18.0
# 105            1     2              15         16.0       0.0      18.0
#
#      altitude  is_weekend  season  month  docking_available  \
# 73        4.0         0.0  Spring    5.0               True
# 79        4.0         0.0  Spring    5.0               True
# 105       4.0         0.0  Spring    5.0               True
#
#            grouped_date  station_id  day
# 73  2023-05-01 18:15:00        31.0    1
# 79  2023-05-01 19:45:00        31.0    1
# 105 2023-05-02 02:15:00        31.0    2

# %%
df_may_filled['station_id'].unique()
# Out:
# array([ 31.,  32.,  57., 378., 446.])

# %%
df_may_filled['hour_minute'] = df_may_filled['hour'] + df_may_filled['grouped_minute'] / 60

# %% [markdown]
# ## 1 station 2023 complete
#
# * The historical data for August '23 does not have data from the 22nd to the 31st due to a technical incident.
# * The historical data for September '23 does not have data from the 1st to the 5th due to a technical incident.

# %%
df_station_57 = df_2023_ml[df_2023_ml['station_id'] == 57]
df_station_57['month'].unique()
df_station_57.sort_values('grouped_date', inplace=True)
df_station_57.columns
# Out:
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_64682/2415883936.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Index(['station_id', 'num_bikes_available',
#        'num_bikes_available_types.mechanical',
#        'num_bikes_available_types.ebike', 'num_docks_available', 'status',
#        'is_renting', 'is_returning', 'year', 'month', 'day', 'hour',
#        'grouped_minute', 'day_of_week', 'is_weekend', 'grouped_date',
#        'docking_available', 'bikes_available', 'bikes_available.mechanical',
#        'bikes_available.ebike', 'season', 'date', 'temperature', 'rainfall',
#        'lat', 'lon', 'altitude', 'post_code', 'capacity', 'address',
#        'district', 'is_holiday', 'percentage_docks_available', 'week_number',
#        'is_summer'],
#       dtype='object')

# %%
features = ['day_of_week', 'hour', 'grouped_minute', 'temperature', 'rainfall',
            'capacity',  'altitude', 'is_weekend', 'season', 'month','docking_available','grouped_date','station_id','day']
df_station_57 = df_station_57[features]

# drop duplicates
print(len(df_station_57))
df_station_57.drop_duplicates(inplace=True)
print(len(df_station_57))

# check for missing values
df_station_57.isna().sum()


#find duplicated records by grouped_date
print(df_station_57['grouped_date'].duplicated().sum())

#keep one record per grouped_date, keep docking_available as the last status of the duplicates
df_station_57.drop_duplicates(subset='grouped_date', keep='last', inplace=True)
print(df_station_57['grouped_date'].duplicated().sum(), len(df_station_57))
# Out:
# 32213
# 32213
# 0
# 0 32213

# %% [markdown]
# ### Missing Data in the Dataset

# %%
# The historical data for August '23 does not have data from the 22nd to the 31st due to a technical incident.
df_station_57[(df_station_57['month'] == 8) & (df_station_57['day'] >= 22)]
#2023-08-22 20:15:00	
# The historical data for September '23 does not have data from the 1st to the 5th due to a technical incident.
df_station_57[(df_station_57['month'] == 9) & (df_station_57['day'] >= 5)]
#2023-09-05 10:30:00
# Out:
#           day_of_week  hour  grouped_minute  temperature  rainfall  capacity  \
# 25334681            1     0               0           29       0.0      25.0
# 25335134            1     0              15           29       0.0      25.0
# 25336231            1     0              30           29       0.0      25.0
# 25336918            1     0              45           29       0.0      25.0
# 25376207            1     1               0           29       0.0      25.0
# ...               ...   ...             ...          ...       ...       ...
# 25373465            1    19              15           30       0.0      25.0
# 25373834            1    19              30           30       0.0      25.0
# 25374842            1    19              45           30       0.0      25.0
# 25379100            1    20               0           30       0.0      25.0
# 25379519            1    20              15           30       0.0      25.0
#
#           altitude  is_weekend  season  month  docking_available  \
# 25334681       4.0           0  Summer      8               True
# 25335134       4.0           0  Summer      8               True
# 25336231       4.0           0  Summer      8               True
# 25336918       4.0           0  Summer      8               True
# 25376207       4.0           0  Summer      8               True
# ...            ...         ...     ...    ...                ...
# 25373465       4.0           0  Summer      8               True
# 25373834       4.0           0  Summer      8               True
# 25374842       4.0           0  Summer      8               True
# 25379100       4.0           0  Summer      8               True
# 25379519       4.0           0  Summer      8               True
#
#                 grouped_date  station_id  day
# 25334681 2023-08-22 00:00:00          57   22
# 25335134 2023-08-22 00:15:00          57   22
# 25336231 2023-08-22 00:30:00          57   22
# 25336918 2023-08-22 00:45:00          57   22
# 25376207 2023-08-22 01:00:00          57   22
# ...                      ...         ...  ...
# 25373465 2023-08-22 19:15:00          57   22
# 25373834 2023-08-22 19:30:00          57   22
# 25374842 2023-08-22 19:45:00          57   22
# 25379100 2023-08-22 20:00:00          57   22
# 25379519 2023-08-22 20:15:00          57   22
#
# [91 rows x 14 columns]

# %% [markdown]
# ### Create Year Datasets

# %%
df_year_dates = pd.date_range(start='2023-01-01', end='2024-01-1', freq='15T')
#Delete jan 1st
df_year_dates = df_year_dates[:-1]
print(len(df_year_dates), 365*24*4)
df_year_dates

# remove the dates with missing data >= 2023-08-22 20:30:00	& <= 2023-09-05 10:15:00
df_year_dates = df_year_dates[(df_year_dates < '2023-08-22 20:30:00') | (df_year_dates > '2023-09-05 10:15:00')]
#validate '2023-08-22 20:30:00' is not in the list
#'2023-08-22 20:30:00' in df_year_dates
print(len(df_year_dates), 365*24*4 - 14*24*4)
# Out:
# 35040 35040
# 33736 33696
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_64682/1557563881.py:1: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_year_dates = pd.date_range(start='2023-01-01', end='2024-01-1', freq='15T')

# %% [markdown]
# ### Check missing values in the Dates

# %%
missing_quarters = ~df_year_dates.isin(df_station_57['grouped_date'])
print(len(df_year_dates[missing_quarters]), len(df_station_57) )
# Out:
# 1523 32213

# %% [markdown]
# ### Fill in with data from previous records

# %%
#add missing quarters interpolated
missing_quarters_df = df_year_dates[missing_quarters]
# create a dataframe with the missing quarters
df_missing = pd.DataFrame(missing_quarters_df, columns=['grouped_date'])
#merge with the original dataframe
df_station_57_merged = pd.merge(df_station_57, df_missing, on='grouped_date', how='outer')
#sort by date
#df_may_merged.sort_values(['station_id', 'grouped_date'], inplace=True)
df_station_57_filled = df_station_57_merged.sort_values(['grouped_date']).fillna(method='ffill')
print(len(df_station_57_filled))
df_station_57_filled.isna().sum()
# Out:
# 33736
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_64682/1568775838.py:9: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_station_57_filled = df_station_57_merged.sort_values(['grouped_date']).fillna(method='ffill')
# /var/folders/1j/zxqksxbs0bg17c_9cj2hm8bh0000gn/T/ipykernel_64682/1568775838.py:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_station_57_filled = df_station_57_merged.sort_values(['grouped_date']).fillna(method='ffill')
# day_of_week          0
# hour                 0
# grouped_minute       0
# temperature          0
# rainfall             0
# capacity             0
# altitude             0
# is_weekend           0
# season               0
# month                0
# docking_available    0
# grouped_date         0
# station_id           0
# day                  0
# dtype: int64

# %% [markdown]
# ### Check Dates field again in case of fill in

# %%
df_station_57_filled['day_of_week'] = df_station_57_filled['grouped_date'].dt.dayofweek
df_station_57_filled['hour'] = df_station_57_filled['grouped_date'].dt.hour
df_station_57_filled['grouped_minute'] = df_station_57_filled['grouped_date'].dt.minute 
df_station_57_filled['day'] = df_station_57_filled['grouped_date'].dt.day
df_station_57_filled.head(3)
# Out:
#    day_of_week  hour  grouped_minute  temperature  rainfall  capacity  \
# 0            6     0               0         15.0       0.0      25.0
# 1            6     0              15         15.0       0.0      25.0
# 2            6     0              30         15.0       0.0      25.0
#
#    altitude  is_weekend  season  month  docking_available        grouped_date  \
# 0       4.0         1.0  Winter    1.0              False 2023-01-01 00:00:00
# 1       4.0         1.0  Winter    1.0              False 2023-01-01 00:15:00
# 2       4.0         1.0  Winter    1.0              False 2023-01-01 00:30:00
#
#    station_id  day
# 0        57.0    1
# 1        57.0    1
# 2        57.0    1

# %%
df_station_57_filled.columns
# Out:
# Index(['day_of_week', 'hour', 'grouped_minute', 'temperature', 'rainfall',
#        'capacity', 'altitude', 'is_weekend', 'season', 'month',
#        'docking_available', 'grouped_date', 'station_id', 'day'],
#       dtype='object')

# %% [markdown]
# ## YEAR

# %% [markdown]
# ### LSTM

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, LeakyReLU, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical



df_lstm_2 = df_station_57_filled.copy()
df_lstm_2['hour_minute'] = df_station_57_filled['hour'] + df_station_57_filled['grouped_minute'] / 60
df_lstm_2['day'] = df_station_57_filled['grouped_date'].dt.day.astype(int)
# Assuming df_rfg is your DataFrame
# Feature and target definition

features = ['day_of_week', 'hour_minute', 'temperature', 'rainfall',
             'season', 'is_weekend', 'month']

target = 'docking_available'

# Encoding categorical features
categorical_features = ['day_of_week',  'is_weekend', 'hour_minute', 'season', 'month']
numerical_features = ['temperature', 'rainfall']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Process features
X = df_lstm_2[features]
y = df_lstm_2[target]

X_processed = preprocessor.fit_transform(X)

# Create sequences
def create_sequences(data, target, sequence_length=24):
    X_seq, y_seq = [], []
    for i in range(len(data) - sequence_length):
        X_seq.append(data[i:i + sequence_length])
        y_seq.append(target[i + sequence_length])
    return np.array(X_seq), np.array(y_seq)

sequence_length = 24
X_processed = X_processed.toarray() 
X_seq, y_seq = create_sequences(X_processed, y.values, sequence_length)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

num_classes = len(np.unique(y))

# Convert target variable to one-hot encoded format
y_train_encoded = to_categorical(y_train, num_classes=num_classes)
y_test_encoded = to_categorical(y_test, num_classes=num_classes)

# Build LSTM model
model = Sequential()
#model.add(LSTM(50, activation='relu', input_shape=(sequence_length, X_seq.shape[2])))
model.add(LSTM(50, activation='relu', input_shape=(sequence_length, X_seq.shape[2]), return_sequences=True))
model.add(LSTM(50, activation='relu'))
#model.add(Dense(9500, activation='relu'))
#model.add(Dense(1024))
#model.add(LeakyReLU(alpha=0.01))
model.add(Dropout(0.2))  # Dropout layer to prevent overfitting
model.add
30
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 45s 67ms/step - accuracy: 0.8268 - loss: 0.3622 - val_accuracy: 0.7857 - val_loss: 0.4347
# Epoch 26/30
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 43s 64ms/step - accuracy: 0.8245 - loss: 0.3548 - val_accuracy: 0.7868 - val_loss: 0.4461
# Epoch 27/30
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 39s 58ms/step - accuracy: 0.8246 - loss: 0.3538 - val_accuracy: 0.7901 - val_loss: 0.4776
# Epoch 28/30
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 38s 57ms/step - accuracy: 0.8255 - loss: 0.3555 - val_accuracy: 0.7766 - val_loss: 0.4583
# Epoch 29/30
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 42s 62ms/step - accuracy: 0.8216 - loss: 0.3659 - val_accuracy: 0.7883 - val_loss: 0.4571
# Epoch 30/30
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 44s 65ms/step - accuracy: 0.8346 - loss: 0.3483 - val_accuracy: 0.7892 - val_loss: 0.4431
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.7939 - loss: 0.4174
# Test Loss: 0.4265289604663849
# Test Accuracy: 0.7919324040412903
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step

# %% [markdown]
# ### Metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix
# Evaluate Accuracy, precision, recall, F1-score, ROC curve, AUC.
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
print("ROC AUC: ", roc_auc)

# Plotting the training history
import matplotlib.pyplot as plt

# Example to show some predictions vs actual
plt.figure(figsize=(12, 6))
plt.plot(y_test[:100], label='Actual')
plt.plot(y_pred[:100], label='Predicted')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()
# Out:
# Accuracy: 0.7919323743141035
# Confusion Matrix:
#  [[1098  833]
#  [ 570 4242]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.66      0.57      0.61      1931
#         True       0.84      0.88      0.86      4812
#
#     accuracy                           0.79      6743
#    macro avg       0.75      0.73      0.73      6743
# weighted avg       0.79      0.79      0.79      6743
#
# Precision:  0.8358620689655173
# Recall:  0.8815461346633416
# F1 Score:  0.8580964903408517
# ROC AUC:  0.7250817157003916

# %%
import plotly.express as px
fig = px.imshow(conf_matrix, text_auto=True,labels=dict(x="Predicted", y="True", color="Count"))
fig.update_layout(title='Confusion Matrix')
fig.update_xaxes(title_text='Predicted', tickvals = [0, 1], ticktext = ['No', 'Yes'])
fig.update_yaxes(title_text='True', tickvals = [0, 1], ticktext = ['No', 'Yes'])
fig.show()

# %% [markdown]
# ### Hyperparameter Tunning

# %% [markdown]
# #### Random Search

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import keras_tuner as kt
from tensorflow.keras.optimizers import Adam

# Assuming df_may_filled is your DataFrame
df_lstm_3 = df_station_57_filled.copy()
df_lstm_3['day'] = df_station_57_filled['grouped_date'].dt.day.astype(int)
df_lstm_3['hour_minute'] = df_station_57_filled['hour'] + df_station_57_filled['grouped_minute'] / 60

features = ['day_of_week', 'hour_minute', 'temperature', 'rainfall',
             'season', 'is_weekend', 'month']
target = 'docking_available'

# Encoding categorical features
categorical_features = ['day_of_week',  'is_weekend', 'hour_minute', 'season', 'month']
numerical_features = ['temperature', 'rainfall']

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

X = df_lstm_3[features]
y = df_lstm_3[target]

X_processed = preprocessor.fit_transform(X)

def create_sequences(data, target, sequence_length=10):
    X_seq, y_seq = [], []
    for i in range(len(data) - sequence_length):
        X_seq.append(data[i:i + sequence_length])
        y_seq.append(target[i + sequence_length])
    return np.array(X_seq), np.array(y_seq)

sequence_length = 24
X_processed = X_processed.toarray() 
X_seq, y_seq = create_sequences(X_processed, y.values, sequence_length)

X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

num_classes = len(np.unique(y))

y_train_encoded = to_categorical(y_train, num_classes=num_classes)
y_test_encoded = to_categorical(y_test, num_classes=num_classes)

def build_model(hp):
    model = Sequential()
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=512, step=32), activation='relu', input_shape=(sequence_length, X_seq.shape[2]), return_sequences=True))
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=512, step=32), activation='relu'))
    model.add(Dropout(hp.Float('dropout', 0.1, 0.5, step=0.1)))
    model.add(Dense(num_classes, activation='softmax'))
    
    model.compile(optimizer=Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='LOG')), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    return model

tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,  # You can adjust the number of trials
    executions_per_trial=3,  # Number of models to be built and fit for each trial
    directory='tuner_dir_year',
    project_name='lstm_tuning'
)
tuner.reload()
tuner.search(X_train, y_train_encoded, epochs=15, batch_size=32, validation_split=0.2, n_jobs=-1)

best_model = tuner.get_best_models(num_models=1)[0]

loss, accuracy = best_model.evaluate(X_test, y_test_encoded)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
#
15
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 362s 537ms/step - accuracy: 0.7504 - loss: 0.5020 - val_accuracy: 0.7514 - val_loss: 0.5388
# Epoch 7/15
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 404s 599ms/step - accuracy: 0.7639 - loss: 0.5218 - val_accuracy: 0.7675 - val_loss: 0.4895
# Epoch 8/15
# 112/675 ━━━━━━━━━━━━━━━━━━━━ 4:57 528ms/step - accuracy: 0.7695 - loss: 0.4703
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 76
#      65     return model
#      67 tuner = kt.RandomSearch(
#      68     build_model,
#      69     objective='val_accuracy',
#    (...)
#      73     project_name='lstm_tuning'
#      74 )
# ---> 76 tuner.search(X_train, y_train_encoded, epochs=15, batch_size=32, validation_split=0.2)
#      78 best_model = tuner.get_best_models(num_models=1)[0]
#      80 loss, accuracy = best_model.evaluate(X_test, y_test_encoded)
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras_tuner/src/engine/base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras_tuner/src/engine/base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras_tuner/src/engine/base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras_tuner/src/engine/tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras_tuner/src/engine/tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras_tuner/src/engine/hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/backend/tensorflow/trainer.py:318, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     316 for step, iterator in epoch_iterator.enumerate_epoch():
#     317     callbacks.on_train_batch_begin(step)
# --> 318     logs = self.train_function(iterator)
#     319     logs = self._pythonify_logs(logs)
#     320     callbacks.on_train_batch_end(step, logs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# #### GRidSearch

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /Users/sol/Library/Python/3.9/lib/python/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /Users/sol/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/sol/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/sol/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/sol/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Assuming df_station_57_filled is your DataFrame
df_lstm_2 = df_station_57_filled.copy()
df_lstm_2['hour_minute'] = df_station_57_filled['hour'] + df_station_57_filled['grouped_minute'] / 60
df_lstm_2['day'] = df_station_57_filled['grouped_date'].dt.day.astype(int)

# Feature and target definition
features = ['day_of_week', 'hour_minute', 'temperature', 'rainfall', 'season', 'is_weekend', 'month']
target = 'docking_available'

# Encoding categorical features
categorical_features = ['day_of_week', 'is_weekend', 'hour_minute', 'season', 'month']
numerical_features = ['temperature', 'rainfall']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Process features
X = df_lstm_2[features]
y = df_lstm_2[target]

X_processed = preprocessor.fit_transform(X)

# Create sequences
def create_sequences(data, target, sequence_length=24):
    X_seq, y_seq = [], []
    for i in range(len(data) - sequence_length):
        X_seq.append(data[i:i + sequence_length])
        y_seq.append(target[i + sequence_length])
    return np.array(X_seq), np.array(y_seq)

sequence_length = 24
X_processed = X_processed.toarray()
X_seq, y_seq = create_sequences(X_processed, y.values, sequence_length)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

num_classes = len(np.unique(y))

# Convert target variable to one-hot encoded format
y_train_encoded = to_categorical(y_train, num_classes=num_classes)
y_test_encoded = to_categorical(y_test, num_classes=num_classes)

# Define the function to build the model
def build_model(units=50, dropout_rate=0.2, learning_rate=0.001):
    model = Sequential()
    model.add(LSTM(units, activation='relu', input_shape=(sequence_length, X_seq.shape[2]), return_sequences=True))
    model.add(LSTM(units, activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Use a custom optimizer with a variable learning rate
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Wrap the model with KerasClassifier
model = KerasClassifier(model=build_model, epochs=25, batch_size=32, verbose=1)

# Define the parameter grid for grid search
param_grid = {
    'model__units': [415, 400],
    'model__dropout_rate': [0.2],
    'model__learning_rate': [0.0001125 , 0.005]
}

# Perform the grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, scoring='accuracy', n_jobs=-1)
grid_result = grid.fit(X_train, y_train_encoded)

# Summarize the results
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print(f"{mean} ({std}) with: {param}")

# Evaluate the best model
best_model = grid_result.best_estimator_
loss, accuracy = best_model.model.evaluate(X_test, y_test_encoded)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")

# Plot the learning curve
history = best_model.model.history
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss/Accuracy')
plt.title('Learning Curve')
plt.legend()
plt.show()
# Out:
# /Users/sol/Library/Python/3.9/lib/python/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Epoch 1/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - accuracy: 0.6884 - loss: 0.6020
# Epoch 2/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7031 - loss: 0.5671
# Epoch 3/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7187 - loss: 0.5551
# Epoch 4/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.7221 - loss: 0.5327
# Epoch 5/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7328 - loss: 0.5177
# Epoch 6/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7460 - loss: 0.5039
# Epoch 7/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7504 - loss: 0.4969
# Epoch 8/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7525 - loss: 0.4910
# Epoch 9/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7566 - loss: 0.4742
# Epoch 10/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.7599 - loss: 0.4742
# Epoch 11/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7759 - loss: 0.4527
# Epoch 12/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.7741 - loss: 0.4513
# Epoch 13/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7807 - loss: 0.4422
# Epoch 14/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.7837 - loss: 0.4386
# Epoch 15/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.7907 - loss: 0.4217
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# /Users/sol/Library/Python/3.9/lib/python/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Epoch 1/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.6990 - loss: 0.6026
# Epoch 2/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.7125 - loss: 0.5559
# Epoch 3/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7262 - loss: 0.5379
# Epoch 4/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7316 - loss: 0.5367
# Epoch 5/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.7431 - loss: 0.5211
# Epoch 6/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7486 - loss: 0.5029
# Epoch 7/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7560 - loss: 0.4848
# Epoch 8/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7671 - loss: 0.4717
# Epoch 9/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.
# Epoch 5/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 25s 45ms/step - accuracy: 0.7030 - loss: 0.6056
# Epoch 6/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.7007 - loss: 14.0535
# Epoch 7/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.7030 - loss: 4.6852
# Epoch 8/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.7039 - loss: 0.6075
# Epoch 9/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.7028 - loss: 0.7433
# Epoch 10/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.7075 - loss: 1.7316
# Epoch 11/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.7073 - loss: 0.6047
# Epoch 12/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.7085 - loss: 0.6031
# Epoch 13/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 23s 41ms/step - accuracy: 0.7100 - loss: 0.6020
# Epoch 14/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 23s 41ms/step - accuracy: 0.7049 - loss: 0.7034
# Epoch 15/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.7091 - loss: 0.6607
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step
# /Users/sol/Library/Python/3.9/lib/python/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Epoch 1/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.6947 - loss: 0.6868
# Epoch 2/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7082 - loss: 0.5784
# Epoch 3/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7040 - loss: 0.5703
# Epoch 4/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7071 - loss: 0.5581
# Epoch 5/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7161 - loss: 0.5473
# Epoch 6/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7197 - loss: 0.5358
# Epoch 7/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7236 - loss: 0.5497
# Epoch 8/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.6798 - loss: 67.8092
# Epoch 9/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.6989 - loss: 0.6130
# Epoch 10/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.7023 - loss: 0.6076
# Epoch 11/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.6996 - loss: 1.1152
# Epoch 12/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.7080 - loss: 0.6105
# Epoch 13/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.7028 - loss: 0.6063
# Epoch 14/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.7048 - loss: 0.6129
# Epoch 15/15
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.6999 - loss: 0.6109
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# /Users/sol/Library/Python/3.9/lib/python/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Epoch 1/15

# %% [markdown]
# ## Month Multiple Stations

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, LeakyReLU, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical



df_lstm_2 = df_may_filled.copy()
df_lstm_2['day'] = df_may_filled['grouped_date'].dt.day.astype(int)
# Assuming df_rfg is your DataFrame
# Feature and target definition

features = ['day_of_week', 'hour_minute', 'temperature', 'rainfall',
            'capacity',  'altitude', 'station_id', 'is_weekend']

target = 'docking_available'

# Encoding categorical features
categorical_features = ['day_of_week',  'is_weekend', 'hour_minute', 'station_id']
numerical_features = ['temperature', 'rainfall', 'capacity', 'altitude']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Process features
X = df_lstm_2[features]
y = df_lstm_2[target]

X_processed = preprocessor.fit_transform(X)

# Create sequences
def create_sequences(data, target, sequence_length=24):
    X_seq, y_seq = [], []
    for i in range(len(data) - sequence_length):
        X_seq.append(data[i:i + sequence_length])
        y_seq.append(target[i + sequence_length])
    return np.array(X_seq), np.array(y_seq)

sequence_length = 10
X_processed = X_processed.toarray() 
X_seq, y_seq = create_sequences(X_processed, y.values, sequence_length)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

num_classes = len(np.unique(y))

# Convert target variable to one-hot encoded format
y_train_encoded = to_categorical(y_train, num_classes=num_classes)
y_test_encoded = to_categorical(y_test, num_classes=num_classes)

# Build LSTM model
model = Sequential()
#model.add(LSTM(50, activation='relu', input_shape=(sequence_length, X_seq.shape[2])))
model.add(LSTM(50, activation='relu', input_shape=(sequence_length, X_seq.shape[2]), return_sequences=True))
model.add(LSTM(50, activation='relu'))
#model.add(Dense(9500, activation='relu'))
#model.add(Dense(1024))
#model.add(LeakyReLU(alpha=0.01))
model.add(Dropout(0.5))  # Dropout layer to prevent overfitting
model.add(Dense(num_classes, activation='softmax'))  # Output layer for classification

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train_encoded, epochs=30, batch_size=32, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test_encoded)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")

# Predict
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)  # Convert probabilities to class labels
# Out:
# Epoch 1/30
# /Users/sol/Library/Python/3.9/lib/python/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.7185 - loss: 0.5994 - val_accuracy: 0.7811 - val_loss: 0.5045
# Epoch 2/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7819 - loss: 0.4970 - val_accuracy: 0.7811 - val_loss: 0.4850
# Epoch 3/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7838 - loss: 0.4802 - val_accuracy: 0.7811 - val_loss: 0.4900
# Epoch 4/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7777 - loss: 0.4593 - val_accuracy: 0.7811 - val_loss: 0.4713
# Epoch 5/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7964 - loss: 0.4083 - val_accuracy: 0.7811 - val_loss: 0.4543
# Epoch 6/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7969 - loss: 0.4081 - val_accuracy: 0.7747 - val_loss: 0.4612
# Epoch 7/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8128 - loss: 0.3721 - val_accuracy: 0.7768 - val_loss: 0.4404
# Epoch 8/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8152 - loss: 0.3556 - val_accuracy: 0.7684 - val_loss: 0.4481
# Epoch 9/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8506 - loss: 0.3077 - val_accuracy: 0.7621 - val_loss: 0.4392
# Epoch 10/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8532 - loss: 0.2999 - val_accuracy: 0.7726 - val_loss: 0.4506
# Epoch 11/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8572 - loss: 0.2891 - val_accuracy: 0.7642 - val_loss: 0.4311
# Epoch 12/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8605 - loss: 0.2822 - val_accuracy: 0.7874 - val_loss: 0.4296
# Epoch 13/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8682 - loss: 0.2459 - val_accuracy: 0.7853 - val_loss: 0.5133
# Epoch 14/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8838 - loss: 0.2351 - val_accuracy: 0.7811 - val_loss: 0.5527
# Epoch 15/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8830 - loss: 0.2232 - val_accuracy: 0.7747 - val_loss: 0.5378
# Epoch 16/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9049 - loss: 0.2051 - val_accuracy: 0.7811 - val_loss: 0.6185
# Epoch 17/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8818 - loss: 0.2456 - val_accuracy: 0.7558 - val_loss: 0.6581
# Epoch 18/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9010 - loss: 0.1985 - val_accuracy: 0.7516 - val_loss: 0.6307
# Epoch 19/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8956 - loss: 0.2050 - val_accuracy: 0.7705 - val_loss: 0.8483
# Epoch 20/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8660 - loss: 0.2845 - val_accuracy: 0.7747 - val_loss: 0.8759
# Epoch 21/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9010 - loss: 0.2064 - val_accuracy: 0.7811 - val_loss: 0.9273
# Epoch 22/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9008 - loss: 0.1934 - val_accuracy: 0.7853 - val_loss: 1.5143
# Epoch 23/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9010 - loss: 0.1890 - val_accuracy: 0.7747 - val_loss: 1.1965
# Epoch 24/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8994 - loss: 0.1856 - val_accuracy: 0.7853 - val_loss: 1.6449
# Epoch 25/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8973 - loss: 0.1873 - val_accuracy: 0.7853 - val_loss: 1.4692
# Epoch 26/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9182 - loss: 0.1662 - val_accuracy: 0.7789 - val_loss: 1.5550
# Epoch 27/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9221 - loss: 0.1550 - val_accuracy: 0.7579 - val_loss: 1.3090
# Epoch 28/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9314 - loss: 0.1519 - val_accuracy: 0.7789 - val_loss: 1.0896
# Epoch 29/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9206 - loss: 0.1619 - val_accuracy: 0.7558 - val_loss: 1.8528
# Epoch 30/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9246 - loss: 0.1644 - val_accuracy: 0.7768 - val_loss: 2.2142
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8485 - loss: 1.7183
# Test Loss: 1.8679746389389038
# Test Accuracy: 0.8282828330993652
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step

# %% [markdown]
# ### Metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix
# Evaluate Accuracy, precision, recall, F1-score, ROC curve, AUC.
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
print("ROC AUC: ", roc_auc)

# Plotting the training history
import matplotlib.pyplot as plt

# Example to show some predictions vs actual
plt.figure(figsize=(12, 6))
plt.plot(y_test[:100], label='Actual')
plt.plot(y_pred[:100], label='Predicted')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()
# Out:
# Accuracy: 0.7666765490661133
# Confusion Matrix:
#  [[1027  897]
#  [ 677 4145]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.60      0.53      0.57      1924
#         True       0.82      0.86      0.84      4822
#
#     accuracy                           0.77      6746
#    macro avg       0.71      0.70      0.70      6746
# weighted avg       0.76      0.77      0.76      6746
#
# Precision:  0.8220944069813566
# Recall:  0.8596018249688926
# F1 Score:  0.8404298459042985
# ROC AUC:  0.6966928043763382

# %% [markdown]
# #### Confusion Matrix

# %%
import plotly.express as px
fig = px.imshow(conf_matrix, text_auto=True,labels=dict(x="Predicted", y="True", color="Count"))
fig.update_layout(title='Confusion Matrix')
fig.update_xaxes(title_text='Predicted', tickvals = [0, 1], ticktext = ['No', 'Yes'])
fig.update_yaxes(title_text='True', tickvals = [0, 1], ticktext = ['No', 'Yes'])
fig.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix
# Evaluate Accuracy, precision, recall, F1-score, ROC curve, AUC.
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
print("ROC AUC: ", roc_auc)
# Out:
# Accuracy: 0.8282828282828283
# Confusion Matrix:
#  [[ 88  59]
#  [ 43 404]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.67      0.60      0.63       147
#         True       0.87      0.90      0.89       447
#
#     accuracy                           0.83       594
#    macro avg       0.77      0.75      0.76       594
# weighted avg       0.82      0.83      0.82       594
#
# Precision:  0.8725701943844493
# Recall:  0.9038031319910514
# F1 Score:  0.8879120879120879
# ROC AUC:  0.7512212938866822

# %%
Accuracy: 0.8265993265993266
Confusion Matrix:
 [[101  46]
 [ 57 390]]
Classification Report:
               precision    recall  f1-score   support

       False       0.64      0.69      0.66       147
        True       0.89      0.87      0.88       447

    accuracy                           0.83       594
   macro avg       0.77      0.78      0.77       594
weighted avg       0.83      0.83      0.83       594

Precision:  0.8944954128440367
Recall:  0.87248322147651
F1 Score:  0.883352208380521
ROC AUC:  0.7797790257042414

# %% [markdown]
# ### Confusion Matrix

# %%
import plotly.express as px
fig = px.imshow(conf_matrix, text_auto=True,labels=dict(x="Predicted", y="True", color="Count"))
fig.update_layout(title='Confusion Matrix')
fig.update_xaxes(title_text='Predicted', tickvals = [0, 1], ticktext = ['No', 'Yes'])
fig.update_yaxes(title_text='True', tickvals = [0, 1], ticktext = ['No', 'Yes'])
fig.show()

# %% [markdown]
# ### Random Search

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import keras_tuner as kt
from tensorflow.keras.optimizers import Adam

# Assuming df_may_filled is your DataFrame
df_lstm_3 = df_may_filled.copy()
df_lstm_3['day'] = df_may_filled['grouped_date'].dt.day.astype(int)

features = ['day_of_week', 'hour_minute', 'temperature', 'rainfall', 'capacity', 'altitude', 'station_id', 'is_weekend']
target = 'docking_available'

categorical_features = ['day_of_week', 'is_weekend', 'hour_minute', 'station_id']
numerical_features = ['temperature', 'rainfall', 'capacity', 'altitude']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

X = df_lstm_3[features]
y = df_lstm_3[target]

X_processed = preprocessor.fit_transform(X)

def create_sequences(data, target, sequence_length=10):
    X_seq, y_seq = [], []
    for i in range(len(data) - sequence_length):
        X_seq.append(data[i:i + sequence_length])
        y_seq.append(target[i + sequence_length])
    return np.array(X_seq), np.array(y_seq)

sequence_length = 10
X_processed = X_processed.toarray() 
X_seq, y_seq = create_sequences(X_processed, y.values, sequence_length)

X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

num_classes = len(np.unique(y))

y_train_encoded = to_categorical(y_train, num_classes=num_classes)
y_test_encoded = to_categorical(y_test, num_classes=num_classes)

def build_model(hp):
    model = Sequential()
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=512, step=32), activation='relu', input_shape=(sequence_length, X_seq.shape[2]), return_sequences=True))
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=512, step=32), activation='relu'))
    model.add(Dropout(hp.Float('dropout', 0.1, 0.5, step=0.1)))
    model.add(Dense(num_classes, activation='softmax'))
    
    model.compile(optimizer=Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='LOG')), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    return model

tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,  # You can adjust the number of trials
    executions_per_trial=3,  # Number of models to be built and fit for each trial
    directory='tuner_dir',
    project_name='lstm_tuning'
)

tuner.search(X_train, y_train_encoded, epochs=15, batch_size=32, validation_split=0.2)

best_model = tuner.get_best_models(num_models=1)[0]

loss, accuracy = best_model.evaluate(X_test, y_test_encoded)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# Trial 10 Complete [00h 05m 31s]
# val_accuracy: 0.804912288983663
#
# Best val_accuracy So Far: 0.8133333325386047
# Total elapsed time: 00h 43m 00s
# /Users/sol/Library/Python/3.9/lib/python/site-packages/keras/src/saving/saving_lib.py:576: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8403 - loss: 0.4452
# Test Loss: 0.4691271483898163
# Test Accuracy: 0.8131313323974609

# %%
best_model.summary()
#tuner.results_summary()
tuner.get_best_hyperparameters()[0].values
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 224)        │       303,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 224)            │       402,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │           450 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 706,498 (2.70 MB)
#  Trainable params: 706,498 (2.70 MB)
#  Non-trainable params: 0 (0.00 B)
# {'units': 224, 'dropout': 0.1, 'learning_rate': 0.0015620297094023163}

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix


# Predict
y_pred_prob = best_model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)  # Convert probabilities to class labels

# Evaluate Accuracy, precision, recall, F1-score, ROC curve, AUC.
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
print("ROC AUC: ", roc_auc)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# Accuracy: 0.8131313131313131
# Confusion Matrix:
#  [[ 83  64]
#  [ 47 400]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.64      0.56      0.60       147
#         True       0.86      0.89      0.88       447
#
#     accuracy                           0.81       594
#    macro avg       0.75      0.73      0.74       594
# weighted avg       0.81      0.81      0.81       594
#
# Precision:  0.8620689655172413
# Recall:  0.8948545861297539
# F1 Score:  0.8781558726673985
# ROC AUC:  0.7297402182349448

# %% [markdown]
# #### save model

# %%
import pickle
# Save the model
filename = '05_lstm_best_model_gridseach.pkl'
pickle.dump(best_model, open(filename, 'wb'))

# %% [markdown]
# ### KFOLD

# %%
from sklearn.model_selection import KFold
import numpy as np

kfold = KFold(n_splits=5, shuffle=True, random_state=42)
for train_index, val_index in kfold.split(X):
    x_train, x_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_val, y_val))
    val_loss = model.evaluate(x_val, y_val)
    print(f'Validation Loss: {val_loss}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 6
#       4 kfold = KFold(n_splits=5, shuffle=True, random_state=42)
#       5 for train_index, val_index in kfold.split(X):
# ----> 6     x_train, x_val = X[train_index], X[val_index]
#       7     y_train, y_val = y[train_index], y[val_index]
#       8     model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_val, y_val))
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([   1,    2,    3,    4,    5,    6,    8,    9,   10,   11,\n       ...\n       2965, 2966, 2967, 2968, 2969, 2970, 2971, 2972, 2973, 2974],\n      dtype='int64', length=2380)] are in the [columns]"

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from tensorflow.keras.utils import to_categorical
import keras_tuner as kt
from tensorflow.keras.optimizers import Adam

# Assuming df_may_filled is your DataFrame
df_lstm_2 = df_may_filled.copy()
df_lstm_2['day'] = df_may_filled['grouped_date'].dt.day.astype(int)

features = ['day_of_week', 'hour_minute', 'temperature', 'rainfall', 'capacity', 'altitude', 'station_id', 'is_weekend']
target = 'docking_available'

categorical_features = ['day_of_week', 'is_weekend', 'hour_minute', 'station_id']
numerical_features = ['temperature', 'rainfall', 'capacity', 'altitude']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

X = df_lstm_2[features]
y = df_lstm_2[target]

X_processed = preprocessor.fit_transform(X)

def create_sequences(data, target, sequence_length=10):
    X_seq, y_seq = [], []
    for i in range(len(data) - sequence_length):
        X_seq.append(data[i:i + sequence_length])
        y_seq.append(target[i + sequence_length])
    return np.array(X_seq), np.array(y_seq)

sequence_length = 10
X_processed = X_processed.toarray() 
X_seq, y_seq = create_sequences(X_processed, y.values, sequence_length)

num_classes = len(np.unique(y))

y_seq_encoded = to_categorical(y_seq, num_classes=num_classes)

def build_model(hp):
    model = Sequential()
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=512, step=32), activation='relu', input_shape=(sequence_length, X_seq.shape[2]), return_sequences=True))
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=512, step=32), activation='relu'))
    model.add(Dropout(hp.Float('dropout', 0.4, 0.5, step=0.1)))
    model.add(Dense(num_classes, activation='softmax'))
    
    model.compile(optimizer=Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='LOG')), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    return model

tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=1,
    directory='tuner_dir',
    project_name='lstm_tuning'
)

# Initialize KFold
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Collect results from each fold
all_val_scores = []

for train_index, val_index in kfold.split(X_seq):
    X_train, X_val = X_seq[train_index], X_seq[val_index]
    y_train, y_val = y_seq_encoded[train_index], y_seq_encoded[val_index]
    
    tuner.search(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_val, y_val))
    
    best_model = tuner.get_best_models(num_models=1)[0]
    val_loss, val_accuracy = best_model.evaluate(X_val, y_val)
    all_val_scores.append((val_loss, val_accuracy))
    print(f'Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy}')

# Average validation scores across all folds
avg_val_loss = np.mean([score[0] for score in all_val_scores])
avg_val_accuracy = np.mean([score[1] for score in all_val_scores])
print(f'Average Validation Loss: {avg_val_loss}, Average Validation Accuracy: {avg_val_accuracy}')

# Evaluate on the test set using the best model
X_train_full, X_test, y_train_full, y_test = train_test_split(X_seq, y_seq_encoded, test_size=0.2, random_state=42)
best_model.fit(X_train_full, y_train_full, epochs=30, batch_size=32)
test_loss, test_accuracy = best_model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')

# Predict on test data
y_pred_prob = best_model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# Reloading Tuner from tuner_dir/lstm_tuning/tuner0.json
# /Users/sol/Library/Python/3.9/lib/python/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# /Users/sol/Library/Python/3.9/lib/python/site-packages/keras/src/saving/saving_lib.py:576: UserWarning:
#
# Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7821 - loss: 0.6295
# Validation Loss: 0.4691270887851715, Validation Accuracy: 0.8131313323974609
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8676 - loss: 0.2199
# Validation Loss: 0.2116670459508896, Validation Accuracy: 0.8802698254585266
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9018 - loss: 0.2085
# Validation Loss: 0.18187227845191956, Validation Accuracy: 0.9190556406974792
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8911 - loss: 0.2197
# Validation Loss: 0.2150040566921234, Validation Accuracy: 0.8937605619430542
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8300 - loss: 0.4248
# Validation Loss: 0.39821913838386536, Validation Accuracy: 0.8482293486595154
# Average Validation Loss: 0.2951779216527939, Average Validation Accuracy: 0.8708893418312073
# Epoch 1/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.8742 - loss: 0.2827
# Epoch 2/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8982 - loss: 0.2132
# Epoch 3/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8847 - loss: 0.2516
# Epoch 4/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9177 - loss: 0.1852
# Epoch 5/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9064 - loss: 0.1928
# Epoch 6/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9274 - loss: 0.1517
# Epoch 7/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9313 - loss: 0.1436
# Epoch 8/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9547 - loss: 0.1192
# Epoch 9/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9337 - loss: 0.1917
# Epoch 10/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9453 - loss: 0.1276
# Epoch 11/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9596 - loss: 0.0901
# Epoch 12/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9656 - loss: 0.0960
# Epoch 13/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9738 - loss: 0.0647
# Epoch 14/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9751 - loss: 0.0604
# Epoch 15/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9787 - loss: 0.0679
# Epoch 16/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9876 - loss: 0.0390
# Epoch 17/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9641 - loss: 0.0954
# Epoch 18/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9728 - loss: 0.0732
# Epoch 19/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9893 - loss: 0.0283
# Epoch 20/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9878 - loss: 0.0324
# Epoch 21/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9949 - loss: 0.0238
# Epoch 22/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9961 - loss: 0.0140
# Epoch 23/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9934 - loss: 0.0160
# Epoch 24/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9838 - loss: 0.0796
# Epoch 25/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9860 - loss: 0.0644
# Epoch 26/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.9914 - loss: 0.0251
# Epoch 27/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9956 - loss: 0.0145
# Epoch 28/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9927 - loss: 0.0180
# Epoch 29/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9974 - loss: 0.0076
# Epoch 30/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9845 - loss: 0.0653
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8097 - loss: 1.0969
# Test Loss: 1.0657306909561157, Test Accuracy: 0.8013467788696289
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, KFold
from tensorflow.keras.utils import to_categorical
import keras_tuner as kt
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# Data Preparation (same as before)
# ... [data preparation steps] ...

# Define the Model-Building Function with Improvements
def build_model(hp):
    model = Sequential()
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=512, step=32), 
                   activation='relu', 
                   input_shape=(sequence_length, X_seq.shape[2]), 
                   return_sequences=True, 
                   kernel_regularizer=l2(0.001)))
    model.add(Dropout(hp.Float('dropout', 0.1, 0.5, step=0.1)))
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=512, step=32), 
                   activation='relu', 
                   kernel_regularizer=l2(0.001)))
    model.add(Dropout(hp.Float('dropout', 0.1, 0.5, step=0.1)))
    model.add(Dense(num_classes, activation='softmax'))
    
    model.compile(optimizer=Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='LOG')), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    return model

tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=1,
    directory='tuner_dir',
    project_name='lstm_tuning'
)

# Initialize KFold
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Collect results from each fold
all_val_scores = []

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-5)

for train_index, val_index in kfold.split(X_seq):
    X_train, X_val = X_seq[train_index], X_seq[val_index]
    y_train, y_val = y_seq_encoded[train_index], y_seq_encoded[val_index]
    
    tuner.search(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_val, y_val), callbacks=[early_stopping, reduce_lr])
    
    best_model = tuner.get_best_models(num_models=1)[0]
    val_loss, val_accuracy = best_model.evaluate(X_val, y_val)
    all_val_scores.append((val_loss, val_accuracy))
    print(f'Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy}')

# Average validation scores across all folds
avg_val_loss = np.mean([score[0] for score in all_val_scores])
avg_val_accuracy = np.mean([score[1] for score in all_val_scores])
print(f'Average Validation Loss: {avg_val_loss}, Average Validation Accuracy: {avg_val_accuracy}')

# Evaluate on the test set using the best model
X_train_full, X_test, y_train_full, y_test = train_test_split(X_seq, y_seq_encoded, test_size=0.2, random_state=42)
best_model.fit(X_train_full, y_train_full, epochs=30, batch_size=32, callbacks=[early_stopping, reduce_lr])
test_loss, test_accuracy = best_model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')

# Predict on test data
y_pred_prob = best_model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# Reloading Tuner from tuner_dir/lstm_tuning/tuner0.json
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7821 - loss: 2.0704
# Validation Loss: 1.9099996089935303, Validation Accuracy: 0.8131313323974609
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8676 - loss: 1.6607
# Validation Loss: 1.652539610862732, Validation Accuracy: 0.8802698254585266
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9018 - loss: 1.6494
# Validation Loss: 1.6227445602416992, Validation Accuracy: 0.9190556406974792
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8911 - loss: 1.6605
# Validation Loss: 1.6558765172958374, Validation Accuracy: 0.8937605619430542
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8300 - loss: 1.8657
# Validation Loss: 1.8390915393829346, Validation Accuracy: 0.8482293486595154
# Average Validation Loss: 1.7360503673553467, Average Validation Accuracy: 0.8708893418312073
# Epoch 1/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8645 - loss: 1.2524 - learning_rate: 0.0016
# Epoch 2/30
#  5/75 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9565 - loss: 0.4687
# /Users/sol/Library/Python/3.9/lib/python/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning:
#
# Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#
# /Users/sol/Library/Python/3.9/lib/python/site-packages/keras/src/callbacks/callback_list.py:96: UserWarning:
#
# Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss,learning_rate.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8939 - loss: 0.5027 - learning_rate: 0.0016
# Epoch 3/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8840 - loss: 0.3851 - learning_rate: 0.0016
# Epoch 4/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8935 - loss: 0.3581 - learning_rate: 0.0016
# Epoch 5/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8713 - loss: 0.3625 - learning_rate: 0.0016
# Epoch 6/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8846 - loss: 0.4717 - learning_rate: 0.0016
# Epoch 7/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8968 - loss: 0.3102 - learning_rate: 0.0016
# Epoch 8/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.9073 - loss: 0.2951 - learning_rate: 0.0016
# Epoch 9/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9173 - loss: 0.2772 - learning_rate: 0.0016
# Epoch 10/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.9174 - loss: 0.2758 - learning_rate: 0.0016
# Epoch 11/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9402 - loss: 0.2321 - learning_rate: 0.0016
# Epoch 12/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9322 - loss: 0.2686 - learning_rate: 0.0016
# Epoch 13/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9396 - loss: 0.2163 - learning_rate: 0.0016
# Epoch 14/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9014 - loss: 0.3050 - learning_rate: 0.0016
# Epoch 15/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9335 - loss: 0.2370 - learning_rate: 0.0016
# Epoch 16/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9536 - loss: 0.2123 - learning_rate: 0.0016
# Epoch 17/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9461 - loss: 0.2210 - learning_rate: 0.0016
# Epoch 18/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9535 - loss: 0.2121 - learning_rate: 0.0016
# Epoch 19/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9521 - loss: 0.2022 - learning_rate: 0.0016
# Epoch 20/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9616 - loss: 0.1929 - learning_rate: 0.0016
# Epoch 21/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9723 - loss: 0.1686 - learning_rate: 0.0016
# Epoch 22/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9381 - loss: 0.2345 - learning_rate: 0.0016
# Epoch 23/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9642 - loss: 0.1874 - learning_rate: 0.0016
# Epoch 24/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9593 - loss: 0.1880 - learning_rate: 0.0016
# Epoch 25/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9690 - loss: 0.1751 - learning_rate: 0.0016
# Epoch 26/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9655 - loss: 0.1974 - learning_rate: 0.0016
# Epoch 27/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9809 - loss: 0.1433 - learning_rate: 0.0016
# Epoch 28/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9702 - loss: 0.1819 - learning_rate: 0.0016
# Epoch 29/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9365 - loss: 0.3747 - learning_rate: 0.0016
# Epoch 30/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9662 - loss: 0.2427 - learning_rate: 0.0016
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8266 - loss: 1.0111
# Test Loss: 1.0268439054489136, Test Accuracy: 0.8249158263206482
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step

# %% [markdown]
# ## SAve model

# %%
# save the model with pickle
import pickle

stations_str = '_'.join([str(x) for x in filter_stations])
now = pd.Timestamp.now()
date = now.strftime("%Y-%m-%d-%H-%M-%S")
added_info = f'mae_{round(mae,5)}_mse_{round(mse,5)}_r2_{round(r2,5)}_stations_{stations_str}_date_{date}'
filename = f'models/0X_model_rfg_{added_info}.pkl'

pickle.dump(pipeline, open(filename, 'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       5 now = pd.Timestamp.now()
#       6 date = now.strftime("%Y-%m-%d-%H-%M-%S")
# ----> 7 added_info = f'mae_{round(mae,5)}_mse_{round(mse,5)}_r2_{round(r2,5)}_stations_{stations_str}_date_{date}'
#       8 filename = f'models/0X_model_rfg_{added_info}.pkl'
#      10 pickle.dump(pipeline, open(filename, 'wb'))
#
# NameError: name 'mae' is not defined

# %% [markdown]
# ## Continous

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.api import VAR
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Assuming df_continuous is your DataFrame and already indexed by datetime
df_var = df_continuous.copy()
df_var['hour_minute'] = df_continuous['hour'] + df_continuous['grouped_minute'] / 60
df_var['day'] = df_continuous['grouped_date'].dt.day.astype(int)

# Set the datetime index
df_var.set_index('grouped_date', inplace=True)

# Features and target definition
features = ['day_of_week', 'hour_minute', 'temperature', 'rainfall', 'season', 'is_weekend', 'month']
target = 'num_docks_available'

# Encoding categorical features
categorical_features = ['day_of_week', 'is_weekend', 'hour_minute', 'season', 'month']
numerical_features = ['temperature', 'rainfall']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(drop='first'), categorical_features)  # Using drop='first' to avoid multicollinearity
    ])

# Process features
X = df_var[features]
y = df_var[target]

X_processed = preprocessor.fit_transform(X)

# Combine processed features and target into one DataFrame
df_processed = pd.DataFrame(X_processed.toarray(), index=df_var.index)
df_processed['docking_available'] = y.values

# Train-test split
train_size = int(len(df_processed) * 0.8)
train, test = df_processed[:train_size], df_processed[train_size:]

# Fit the VAR model
model = VAR(train)
try:
    fitted_model = model.fit(maxlags=15, ic='aic')
except np.linalg.LinAlgError:
    # Reduce the number of lags if there's a LinAlgError
    fitted_model = model.fit(maxlags=5, ic='aic')

# Forecast
n_forecast = len(test)
forecast_input = train.values[-fitted_model.k_ar:]
forecast = fitted_model.forecast(y=forecast_input, steps=n_forecast)

# Convert forecast to DataFrame
forecast_df = pd.DataFrame(forecast, index=test.index, columns=test.columns)

# Evaluate the model
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(test['docking_available'], forecast_df['docking_available'])
print(f'Test MSE: {mse}')

# Plot the results
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(train.index, train['docking_available'], label='Train')
plt.plot(test.index, test['docking_available'], label='Test')
plt.plot(forecast_df.index, forecast_df['docking_available'], label='Forecast')
plt.legend(loc='upper left')
plt.title('VAR Model Forecast')
plt.show()
# Out:
# /Users/sol/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /Users/sol/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[80], line 45
#      44 try:
# ---> 45     fitted_model = model.fit(maxlags=15, ic='aic')
#      46 except np.linalg.LinAlgError:
#      47     # Reduce the number of lags if there's a LinAlgError
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/vector_ar/var_model.py:658, in VAR.fit(self, maxlags, method, ic, trend, verbose)
#     657 if ic is not None:
# --> 658     selections = self.select_order(maxlags=maxlags)
#     659     if not hasattr(selections, ic):
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/vector_ar/var_model.py:823, in VAR.select_order(self, maxlags, trend)
#     821 result = self._estimate_var(p, offset=maxlags - p, trend=trend)
# --> 823 for k, v in result.info_criteria.items():
#     824     ics[k].append(v)
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/base/wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      32     pass
# ---> 34 obj = getattr(results, attr)
#      35 data = results.model.data
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/vector_ar/var_model.py:2289, in VARResults.info_criteria(self)
#    2288 if self.df_resid:
# -> 2289     ld = logdet_symm(self.sigma_u_mle)
#    2290 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/tools/linalg.py:28, in logdet_symm(m, check_symm)
#      27         raise ValueError("m is not symmetric.")
# ---> 28 c, _ = linalg.cho_factor(m, lower=True)
#      29 return 2*np.sum(np.log(c.diagonal()))
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/linalg/_decomp_cholesky.py:153, in cho_factor(a, lower, overwrite_a, check_finite)
#      94 """
#      95 Compute the Cholesky decomposition of a matrix, to use in cho_solve
#      96
#    (...)
#     151
#     152 """
# --> 153 c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=False,
#     154                      check_finite=check_finite)
#     155 return c, lower
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/linalg/_decomp_cholesky.py:36, in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      35 if info > 0:
# ---> 36     raise LinAlgError("%d-th leading minor of the array is not positive "
#      37                       "definite" % info)
#      38 if info < 0:
#
# LinAlgError: 111-th leading minor of the array is not positive definite
#
# During handling of the above exception, another exception occurred:
#
# LinAlgError                               Traceback (most recent call last)
# Cell In[80], line 48
#      45     fitted_model = model.fit(maxlags=15, ic='aic')
#      46 except np.linalg.LinAlgError:
#      47     # Reduce the number of lags if there's a LinAlgError
# ---> 48     fitted_model = model.fit(maxlags=5, ic='aic')
#      50 # Forecast
#      51 n_forecast = len(test)
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/vector_ar/var_model.py:658, in VAR.fit(self, maxlags, method, ic, trend, verbose)
#     655     raise ValueError(f"trend '{trend}' not supported for VAR")
#     657 if ic is not None:
# --> 658     selections = self.select_order(maxlags=maxlags)
#     659     if not hasattr(selections, ic):
#     660         raise ValueError(
#     661             "%s not recognized, must be among %s"
#     662             % (ic, sorted(selections))
#     663         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/vector_ar/var_model.py:823, in VAR.select_order(self, maxlags, trend)
#     818 for p in range(p_min, maxlags + 1):
#     819     # exclude some periods to same amount of data used for each lag
#     820     # order
#     821     result = self._estimate_var(p, offset=maxlags - p, trend=trend)
# --> 823     for k, v in result.info_criteria.items():
#     824         ics[k].append(v)
#     826 selected_orders = {
#     827     k: np.array(v).argmin() + p_min for k, v in ics.items()
#     828 }
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/base/wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      31 except AttributeError:
#      32     pass
# ---> 34 obj = getattr(results, attr)
#      35 data = results.model.data
#      36 how = self._wrap_attrs.get(attr)
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/vector_ar/var_model.py:2289, in VARResults.info_criteria(self)
#    2287 free_params = lag_order * neqs ** 2 + neqs * self.k_exog
#    2288 if self.df_resid:
# -> 2289     ld = logdet_symm(self.sigma_u_mle)
#    2290 else:
#    2291     ld = -np.inf
#
# File ~/Library/Python/3.9/lib/python/site-packages/statsmodels/tools/linalg.py:28, in logdet_symm(m, check_symm)
#      26     if not np.all(m == m.T):  # would be nice to short-circuit check
#      27         raise ValueError("m is not symmetric.")
# ---> 28 c, _ = linalg.cho_factor(m, lower=True)
#      29 return 2*np.sum(np.log(c.diagonal()))
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/linalg/_decomp_cholesky.py:153, in cho_factor(a, lower, overwrite_a, check_finite)
#      93 def cho_factor(a, lower=False, overwrite_a=False, check_finite=True):
#      94     """
#      95     Compute the Cholesky decomposition of a matrix, to use in cho_solve
#      96
#    (...)
#     151
#     152     """
# --> 153     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=False,
#     154                          check_finite=check_finite)
#     155     return c, lower
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/linalg/_decomp_cholesky.py:36, in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      34 c, info = potrf(a1, lower=lower, overwrite_a=overwrite_a, clean=clean)
#      35 if info > 0:
# ---> 36     raise LinAlgError("%d-th leading minor of the array is not positive "
#      37                       "definite" % info)
#      38 if info < 0:
#      39     raise ValueError(f'LAPACK reported an illegal value in {-info}-th argument'
#      40                      'on entry to "POTRF".')
#
# LinAlgError: 9-th leading minor of the array is not positive definite

# %%
# %pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting statsmodels
#   Downloading statsmodels-0.14.2-cp39-cp39-macosx_10_9_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy>=1.22.3 in /Users/sol/Library/Python/3.9/lib/python/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/sol/Library/Python/3.9/lib/python/site-packages (from statsmodels) (1.13.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Users/sol/Library/Python/3.9/lib/python/site-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in /Users/sol/Library/Python/3.9/lib/python/site-packages (from statsmodels) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sol/Library/Python/3.9/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sol/Library/Python/3.9/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sol/Library/Python/3.9/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from patsy>=0.5.6->statsmodels) (1.15.0)
# Downloading statsmodels-0.14.2-cp39-cp39-macosx_10_9_x86_64.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 6.4 MB/s eta 0:00:0000:010:01
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### LSTM Continuous

# %%
df_continuous = df_2023_ml[df_2023_ml['station_id'] == 57].copy()

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, LeakyReLU, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Assuming df_lstm_2 is your DataFrame
df_lstm_3 = df_continuous.copy()
df_lstm_3['hour_minute'] = df_station_57_filled['hour'] + df_station_57_filled['grouped_minute'] / 60
df_lstm_3['day'] = df_station_57_filled['grouped_date'].dt.day.astype(int)

# Set the datetime index
df_lstm_3.set_index('grouped_date', inplace=True)

# Features and target definition
features = ['day_of_week', 'hour_minute', 'temperature', 'rainfall', 'season', 'is_weekend', 'month']
target = 'num_docks_available'

# Encoding categorical features
categorical_features = ['day_of_week', 'is_weekend', 'hour_minute', 'season', 'month']
numerical_features = ['temperature', 'rainfall']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Process features
X = df_lstm_3[features]
y = df_lstm_3[target]

X_processed = preprocessor.fit_transform(X)

# Create sequences
def create_sequences(data, target, sequence_length=24):
    X_seq, y_seq = [], []
    for i in range(len(data) - sequence_length):
        X_seq.append(data[i:i + sequence_length])
        y_seq.append(target[i + sequence_length])
    return np.array(X_seq), np.array(y_seq)

sequence_length = 24
X_processed = X_processed.toarray()
X_seq, y_seq = create_sequences(X_processed, y.values, sequence_length)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# Build LSTM model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(sequence_length, X_seq.shape[2]), return_sequences=True))
model.add(LSTM(50, activation='relu'))
model.add(Dropout(0.2))  # Dropout layer to prevent overfitting
model.add(Dense(1))  # Output layer for regression

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")

# Predict
y_pred = model.predict(X_test)

# Plot the results
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend(loc='upper left')
plt.title('Multivariate LSTM Forecast')
plt.show()
# Out:
# /Users/sol/Library/Python/3.9/lib/python/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Epoch 1/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - loss: 37.1814 - val_loss: 15.2188
# Epoch 2/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 14.6842 - val_loss: 13.7953
# Epoch 3/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 25s 26ms/step - loss: 13.9690 - val_loss: 12.6925
# Epoch 4/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - loss: 13.2296 - val_loss: 13.0201
# Epoch 5/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 46s 47ms/step - loss: 13.0000 - val_loss: 12.3423
# Epoch 6/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 47s 49ms/step - loss: 12.6050 - val_loss: 12.0556
# Epoch 7/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 44s 46ms/step - loss: 11.9252 - val_loss: 12.3215
# Epoch 8/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 46s 47ms/step - loss: 12.0433 - val_loss: 11.5801
# Epoch 9/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 51s 52ms/step - loss: 11.9636 - val_loss: 11.2716
# Epoch 10/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - loss: 11.4218 - val_loss: 11.1261
# Epoch 11/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 45s 46ms/step - loss: 11.4089 - val_loss: 11.5789
# Epoch 12/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 45s 46ms/step - loss: 11.4669 - val_loss: 13.9866
# Epoch 13/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 45s 46ms/step - loss: 11.8417 - val_loss: 10.8468
# Epoch 14/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 38s 39ms/step - loss: 10.9969 - val_loss: 11.1365
# Epoch 15/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 33s 34ms/step - loss: 10.7118 - val_loss: 11.1099
# Epoch 16/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 29s 29ms/step - loss: 10.4866 - val_loss: 10.8249
# Epoch 17/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 28s 29ms/step - loss: 10.2498 - val_loss: 10.3880
# Epoch 18/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 28s 29ms/step - loss: 10.3980 - val_loss: 10.1067
# Epoch 19/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 31s 32ms/step - loss: 10.2857 - val_loss: 9.9398
# Epoch 20/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 39s 40ms/step - loss: 9.5897 - val_loss: 10.0702
# Epoch 21/30
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 44s 46ms/step - loss: 9.6495 - val_loss: 10.0193
# Epoch 22/30
# 220/968 ━━━━━━━━━━━━━━━━━━━━ 33s 45ms/step - loss: 9.1550
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 64
#      61 model.compile(optimizer='adam', loss='mean_squared_error')
#      63 # Train the model
# ---> 64 history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2)
#      66 # Evaluate the model
#      67 loss = model.evaluate(X_test, y_test)
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/backend/tensorflow/trainer.py:318, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     316 for step, iterator in epoch_iterator.enumerate_epoch():
#     317     callbacks.on_train_batch_begin(step)
# --> 318     logs = self.train_function(iterator)
#     319     logs = self._pythonify_logs(logs)
#     320     callbacks.on_train_batch_end(step, logs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Assuming df_continuous is your DataFrame and 'num_docks_available' is the continuous variable you want to predict
df = df_continuous.copy()

# Features and target definition
features = ['day_of_week', 'hour', 'grouped_minute', 'temperature', 'rainfall', 'season', 'is_weekend', 'month']
target = 'num_docks_available'

# Encoding categorical features
categorical_features = ['day_of_week', 'is_weekend', 'hour', 'grouped_minute', 'season', 'month']
numerical_features = ['temperature', 'rainfall']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Process features
X = df[features]
y = df[target]

X_processed = preprocessor.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)

# Fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Evaluate the model
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

print(f'Train MSE: {train_mse}')
print(f'Test MSE: {test_mse}')
print(f'Train R2: {train_r2}')
print(f'Test R2: {test_r2}')

# Plot the results
plt.figure(figsize=(12, 6))
plt.scatter(y_train, y_train_pred, label='Train', alpha=0.7)
plt.scatter(y_test, y_test_pred, label='Test', alpha=0.7)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=3)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('Linear Regression Predictions')
plt.legend()
plt.show()
# Out:
# Train MSE: 16.23224007004583
# Test MSE: 16.290421025280246
# Train R2: 0.20999594780631914
# Test R2: 0.2041944112281413
